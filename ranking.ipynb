# %% [markdown]
# <a href="https://colab.research.google.com/github/Sj-20/Ranking/blob/main/ranking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing relevant libraries.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
Loading the dataset

# %%
rs=pd.read_csv('/content/drive/My Drive/Ranking System I.csv')

# %% [markdown]
# To view the head of the dataset.

# %%
rs.head()
# Out:
#    world_rank                            institution  ...   score  year
# 0           1                     Harvard University  ...  100.00  2012
# 1           2  Massachusetts Institute of Technology  ...   91.67  2012
# 2           3                    Stanford University  ...   89.50  2012
# 3           4                University of Cambridge  ...   86.17  2012
# 4           5     California Institute of Technology  ...   85.21  2012
#
# [5 rows x 14 columns]

# %% [markdown]
# Viewing the dimensions of the array of the tuple.

# %%
rs.shape
# Out:
# (2200, 14)

# %% [markdown]
# To check null values.

# %%
rs.isnull().all()
# Out:
# world_rank              False
# institution             False
# country                 False
# national_rank           False
# quality_of_education    False
# alumni_employment       False
# quality_of_faculty      False
# publications            False
# influence               False
# citations               False
# broad_impact            False
# patents                 False
# score                   False
# year                    False
# dtype: bool

# %% [markdown]
# To check null values.

# %%
rs.isnull().any()
# Out:
# world_rank              False
# institution             False
# country                 False
# national_rank           False
# quality_of_education    False
# alumni_employment       False
# quality_of_faculty      False
# publications            False
# influence               False
# citations               False
# broad_impact             True
# patents                 False
# score                   False
# year                    False
# dtype: bool

# %%
To check null values between the dataframe and broad_impact column.

# %%
rs= rs[~rs.broad_impact.isnull()]

# %% [markdown]
# Using round function for returning the rounded version of a specific number.

# %%
round(100*(rs.isnull().sum()/len(rs.index)),2)
# Out:
# world_rank              0.0
# institution             0.0
# country                 0.0
# national_rank           0.0
# quality_of_education    0.0
# alumni_employment       0.0
# quality_of_faculty      0.0
# publications            0.0
# influence               0.0
# citations               0.0
# broad_impact            0.0
# patents                 0.0
# score                   0.0
# year                    0.0
# dtype: float64

# %% [markdown]
# To drop year column

# %%
rs = rs.drop('year',axis='columns')

# %%
to view the results after dropping.

# %%
rs.head()
# Out:
#      world_rank                            institution  ... patents   score
# 200           1                     Harvard University  ...       2  100.00
# 201           2                    Stanford University  ...       6   99.09
# 202           3  Massachusetts Institute of Technology  ...       1   98.69
# 203           4                University of Cambridge  ...      48   97.64
# 204           5                   University of Oxford  ...      16   97.51
#
# [5 rows x 13 columns]

# %% [markdown]
# To see the influence of each column contributing to the world rank column.

# %%
sns.pairplot(rs,x_vars = ['national_rank','quality_of_education','alumni_employment',
                       'quality_of_faculty','publications'],y_vars = 'world_rank')
sns.pairplot(rs,x_vars = ['influence','citations','broad_impact',
                       'patents','score'],y_vars = 'world_rank')
plt.show()

# %% [markdown]
# To view the heatmap.

# %%
plt.figure(figsize=(10,10))
sns.heatmap(rs.corr(),annot = True,cmap='cool')

# %% [markdown]
# To see relationship between world_rank and broad_impact.

# %%
sns.lmplot(x = 'broad_impact',y= 'world_rank',data = rs)
plt.title('world rank vs broad impact')
plt.show()

# %% [markdown]
# Plotting more graph

# %%
sns.lmplot(x = 'influence',y= 'world_rank',data = rs)
plt.title('world rank vs broad impact')
plt.show()

# %%
rs.quality_of_education
# Out:
# 200       1
# 201      11
# 202       3
# 203       2
# 204       7
#        ...
# 2195    367
# 2196    236
# 2197    367
# 2198    367
# 2199    367
# Name: quality_of_education, Length: 2000, dtype: int64

# %%
rs.world_rank
# Out:
# 200        1
# 201        2
# 202        3
# 203        4
# 204        5
#         ...
# 2195     996
# 2196     997
# 2197     998
# 2198     999
# 2199    1000
# Name: world_rank, Length: 2000, dtype: int64

# %% [markdown]
# Finding the correlation between quality of education and world rank.

# %%
Corr=np.corrcoef(rs.quality_of_education,rs.world_rank)
Corr
# Out:
# array([[1.        , 0.58764575],
#        [0.58764575, 1.        ]])

# %% [markdown]
# Finding the correlation of quality of faculty and world rank.

# %%
Corr=np.corrcoef(rs.quality_of_faculty,rs.world_rank)
Corr
# Out:
# array([[1.        , 0.57158109],
#        [0.57158109, 1.        ]])
